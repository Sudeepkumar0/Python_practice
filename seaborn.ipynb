# %%
import seaborn as sns

#distribution plots
#displot
#jopintplot
#pairplot

#these plot baiscally work with featurs and values should be either integer or float

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.size
# Out:
# 1708

# %%
df.corr()
# Out:
# C:\Users\SUDEEP\AppData\Local\Temp\ipykernel_15976\1886530979.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\SUDEEP\AppData\Local\Temp\ipykernel_15976\1072140413.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
sns.jointplot(x='tip', y='total_bill', data=df, kind='hex')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='day')

# %%
sns.displot(df['tip'], kde=True, bins=10)

# %%
sns.histplot(df['tip'], bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
#Categorial Plots

#box plot
#viollnplot
#countplot
#bar plot

sns.countplot(x='sex', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='smoker', data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='tip', data=df)
# Out:
# <Axes: xlabel='tip', ylabel='count'>

# %%
sns.countplot(x='day', data=df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(y='day', data=df)
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
sns.barplot(x='day', y='sex', data=df)
# Out:
# <Axes: xlabel='day', ylabel='sex'>

# %%
sns.barplot(x='day', y='tip', data=df)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.barplot(x='day', y='total_bill', data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x='sex', y='total_bill', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
print(df.columns)
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.boxplot(x='sex', y='total_bill', data=df, palette='rainbow', hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x='total_bill', y='sex', data=df, palette='rainbow', hue='day')
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
sns.violinplot(x='total_bill', y='sex', data=df, palette='rainbow', hue='day')
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
iris = sns.load_dataset("iris")

iris.head(6)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
sns.pairplot(iris)

# %%
iris.corr()
# Out:
# C:\Users\SUDEEP\AppData\Local\Temp\ipykernel_15976\2054728610.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr())
# Out:
# C:\Users\SUDEEP\AppData\Local\Temp\ipykernel_15976\3429999767.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris.corr())
# <Axes: >

# %%
sns.jointplot(x='sepal_length', y='petal_length', data=iris, kind='reg')

# %%
sns.jointplot(x='sepal_length', y='petal_length', data=iris, kind='resid')

# %%
sns.jointplot(x='sepal_length', y='petal_length', data=iris, kind='hist')
